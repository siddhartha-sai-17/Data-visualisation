# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhartha-sai-17/Data-visualisation/blob/main/EDA_Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Explorative Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.shape
# Out:
# (891, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
# missing value analysis
missing = pd.DataFrame({
    'missing count ': df.isnull().sum(),
    'missing percentage' : (df.isnull().sum()/len(df)) * 100
})
missing.sort_values(by='missing percentage' , ascending = False)
# Out:
#              missing count   missing percentage
# embark_town               2            0.224467
# survived                  0            0.000000
# sex                       0            0.000000
# age                       0            0.000000
# sibsp                     0            0.000000
# pclass                    0            0.000000
# parch                     0            0.000000
# fare                      0            0.000000
# class                     0            0.000000
# embarked                  0            0.000000
# who                       0            0.000000
# adult_male                0            0.000000
# alive                     0            0.000000
# alone                     0            0.000000

# %%
# Handling missing values

# %%
# Fill numeric missing values with mean
df['age'] = df['age'].fillna(df['age'].mean())

# Fill categorical missing values with mode
df['embarked'] = df['embarked'].fillna(df['embarked'].mode()[0])

# Drop 'deck' column
df.drop(columns=['deck'], inplace=True)

# Print missing values after cleaning
print("Missing values after cleaning:\n", df.isnull().sum())
# Out:
# Missing values after cleaning:
#  survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    2
# alive          0
# alone          0
# dtype: int64

# %%
print("Duplicate rows", df.duplicated().sum())
# Out:
# Duplicate rows 111

# %%
df['class'] = df['class'] .astype('category')
df['sex'] = df['sex'] . astype('category')
df['embarked'] = df['embarked'] .astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    category
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    category
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(3), float64(2), int64(4), object(3)
# memory usage: 67.5+ KB

# %%
nums_col = df.select_dtypes(include=['float64','int64']).columns
df[nums_col].describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.002015    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   29.699118    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
sns.histplot(df['age'],bins =30,kde=True,color='skyblue')
plt.title("Age ditribution of Passengers")
# Out:
# Text(0.5, 1.0, 'Age ditribution of Passengers')

# %%
sns.boxplot(x=df['fare'],color='orange')
plt.title("Face Distribution with outliers")
plt.show()

# %%
cat_cols = df.select_dtypes('category').columns
for col in cat_cols:
  sns.catplot(x=col,data=df)
  plt.title("Count of class")
  plt.show()

# %%
cat_cols = df.select_dtypes('category').columns
for col in cat_cols:
  sns.catplot(x=col,data=df)
  plt.title(f"Count of {col}")
  plt.show()

# %%
sns.norplot("Fared ,u='fare",data=df)
plt.title("Survival sount by gemfer")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-3423901130.py in <cell line: 0>()
# ----> 1 sns.norplot("Fared ,u='fare",data=df)
#       2 plt.title("Survival sount by gemfer")
#       3 plt.show()
#
# AttributeError: module 'seaborn' has no attribute 'norplot'

# %%
# Calculate IQR
q1 = df['fare'].quantile(0.25)
q3 = df['fare'].quantile(0.75)
IQR = q3 - q1

# Define outlier boundaries
lower = q1 - 1.5 * IQR
upper = q3 + 1.5 * IQR

# Find outliers
outliers = df[(df['fare'] < lower) | (df['fare'] > upper)]
print("Number of outliers in fare:", len(outliers))

# Cap outliers
df['fare_capped'] = df['fare'].clip(lower, upper)

# Boxplot after capping
sns.boxplot(x=df['fare_capped'])
plt.title("Fare after outlier capping")
plt.show()
# Out:
# Number of outliers in fare: 116
