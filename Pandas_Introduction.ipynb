# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhartha-sai-17/Data-visualisation/blob/main/Pandas_Introduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas is a python library used for working with data sets

# %%
# Pandas can clean messy data stes and make them readable and relevant

# %%
pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
# Pandas Series is like a column in a table

# %%
# It is a 1D array which hold any type of data

# %%
a_list = [1,2,3,4,5]
series = pd.Series(a_list,index=['1st','2nd','3rd','4th','5th'])
series
# Out:
# 1st    1
# 2nd    2
# 3rd    3
# 4th    4
# 5th    5
# dtype: int64

# %%
a_dict = {'1st':1,'2nd':2,'3rd':3,'4th':4,'5th':5}

# %%
k = pd.Series(a_dict)
k
# Out:
# 1st    1
# 2nd    2
# 3rd    3
# 4th    4
# 5th    5
# dtype: int64

# %%
student_scores = {'Charlie':45,'Eve':98,'Adam':100,'Johnas':92,'Martha':89,'Hannah':100,'Mikkel':67,'Katherina':72,'Noah':56,'helga':43}

# %%
scores = pd.Series(student_scores)

# %%
scores
# Out:
# Charlie       45
# Eve           98
# Adam         100
# Johnas        92
# Martha        89
# Hannah       100
# Mikkel        67
# Katherina     72
# Noah          56
# helga         43
# dtype: int64

# %%
print(scores[0])
# Out:
# 45
# /tmp/ipython-input-1986512969.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(scores[0])

# %%
print(scores[1])
# Out:
# 98
# /tmp/ipython-input-4101463214.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(scores[1])

# %%
scores = scores + 5
scores
# Out:
# Charlie       50
# Eve          103
# Adam         105
# Johnas        97
# Martha        94
# Hannah       105
# Mikkel        72
# Katherina     77
# Noah          61
# helga         48
# dtype: int64

# %%
print(scores[scores>90])
# Out:
# Eve       103
# Adam      105
# Johnas     97
# Martha     94
# Hannah    105
# dtype: int64

# %%
print(scores.mean())
# Out:
# 81.2

# %%
# DataFrame is a 2D array with rows and columns

# %%
# We can pass lists,series,arrays

# %%
arr = np.array([[25,85],[34,23],[43,40],[21,56]])

# %%
ser = pd.DataFrame(arr,index=['sid','var','rak','amar'],columns=['age','marks'])
ser
# Out:
#       age  marks
# sid    25     85
# var    34     23
# rak    43     40
# amar   21     56

# %%
# To display only values
ser.values
# Out:
# array([[25, 85],
#        [34, 23],
#        [43, 40],
#        [21, 56]])

# %%
# To display only index
ser.index
# Out:
# Index(['sid', 'var', 'rak', 'amar'], dtype='object')

# %%
# To display age
ser.age
# Out:
# sid     25
# var     34
# rak     43
# amar    21
# Name: age, dtype: int64

# %%
a_dict = {'name': {'si':'Siddhartha','amar':'Amarnath','rak':'Rakesh','ki':'Kiran','ni':'Nihaar'},
          'age':{'si':20,'amar':19,'rak':21,'ki':20,'ni':22},
          'maeks':{'si':98,'amar':97,'rak':93,'ki':87,'ni':91}}
ser = pd.DataFrame(a_dict)
ser
# Out:
#             name  age  maeks
# si    Siddhartha   20     98
# amar    Amarnath   19     97
# rak       Rakesh   21     93
# ki         Kiran   20     87
# ni        Nihaar   22     91

# %%
ser.values
# Out:
# array([['Siddhartha', 20, 98],
#        ['Amarnath', 19, 97],
#        ['Rakesh', 21, 93],
#        ['Kiran', 20, 87],
#        ['Nihaar', 22, 91]], dtype=object)

# %%
ser.index
# Out:
# Index(['si', 'amar', 'rak', 'ki', 'ni'], dtype='object')

# %%
ser.columns
# Out:
# Index(['name', 'age', 'maeks'], dtype='object')

# %%
type(ser.values)
# Out:
# numpy.ndarray

# %%
ser.values.ndim
# Out:
# 2

# %%
ser1 = pd.Series(['Siddhartha','Amarnath','Rakesh'],index=['si','amar','rak'])
ser2 = pd.Series([25,23,19],index=['si','amar','rak'])
ser3=  pd.Series([19,18,19],index=['si','amar','rak'])

# %%
a_dict = {
    'name':ser1,
    'marks':ser2,
    'age':ser3
}

# %%
 k = pd.DataFrame(a_dict)
 k
# Out:
#             name  marks  age
# si    Siddhartha     25   19
# amar    Amarnath     23   18
# rak       Rakesh     19   19

# %%
highest_marks = a_dict['marks'].max()

# %%
top_student = k[k['marks'] == highest_marks]

# %%
print(top_student)
# Out:
#           name  marks  age
# si  Siddhartha     25   19

# %%
k.loc['ki'] = ['Kiran','21',20] #to add student in the dataset

# %%
k
# Out:
#             name marks  age
# si    Siddhartha    25   19
# amar    Amarnath    23   18
# rak       Rakesh    19   19
# ki         Kiran    21   20

# %%
age_19 = k[k['age']>=19]

# %%
print(age_19)
# Out:
#            name marks  age
# si   Siddhartha    25   19
# rak      Rakesh    19   19
# ki        Kiran    21   20

# %%
# Ensure marks column is numeric
k['marks'] = pd.to_numeric(k['marks'], errors='coerce')

# Now add 10 points to students with marks < 80
k.loc[k['marks'] < 80, 'marks'] += 10
print(k)

# Calculate average
average_marks = k['marks'].mean()
print(f"Average marks after bonus: {average_marks:.2f}")
# Out:
#             name  marks  age
# si    Siddhartha     65   19
# amar    Amarnath     63   18
# rak       Rakesh     59   19
# ki         Kiran     61   20
# Average marks after bonus: 62.00

# %%
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2985678062.py in <cell line: 0>()
# ----> 1 drive.mount('/content/drive')
#
# NameError: name 'drive' is not defined

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-3785717117.py in <cell line: 0>()
# ----> 1 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import os
os._exit(00)

# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
import pandas as pd

# Upload CSV
uploaded = files.upload()

# Read the CSV
df = pd.read_csv(list(uploaded.keys())[0])
print(df.head())
# Out:
#      <input type="file" id="files-a9bdcdb4-d689-4412-8ddb-e51a4cecf015" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9bdcdb4-d689-4412-8ddb-e51a4cecf015">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
file_path = '/content/drive/MyDrive/Colab Notebooks/data.csv'
if os.path.exists(file_path):
    print("File exists in Drive!")
else:
    print("File not found in Drive.")
# Out:
# File exists in Drive!

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Duration        Date  Pulse  Maxpulse  Calories
# 0        60  2020/12/01    110       130     409.1
# 1        60  2020/12/02    117       145     479.0
# 2        60  2020/12/03    103       135     340.0
# 3        45  2020/12/04    109       175     282.4
# 4        45  2020/12/05    117       148     406.0

# %%
df.tail()
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 27        60  2020/12/27     92       118     241.0
# 28        60  2020/12/28    103       132       NaN
# 29        60  2020/12/29    100       132     280.0
# 30        60  2020/12/30    102       129     380.3
# 31        60  2020/12/31     92       115     243.0

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# ...

# %%
df.isnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0      False  False  False     False     False
# 1      False  False  False     False     False
# 2      False  False  False     False     False
# 3      False  False  False     False     False
# 4      False  False  False     False     False
# 5      False  False  False     False     False
# 6      False  False  False     False     False
# 7      False  False  False     False     False
# 8      False  False  False     False     False
# 9      False  False  False     False     False
# 10     False  False  False     False     False
# 11     False  False  False     False     False
# 12     False  False  False     False     False
# 13     False  False  False     False     False
# 14     False  False  False     False     False
# 15     False  False  False     False     False
# 16     False  False  False     False     False
# 17     False  False  False     False     False
# 18     False  False  False     False      True
# ...

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
new_df = df.dropna() #It drops the null values

# %%
print(new_df.to_string())
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df.fillna(130,inplace=True) #It replaces the null values with 130

# %%
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
x = df["Calories"].median() #It gives the mean
df.fillna({"Calories":x}).inplace = True
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
x = df["Calories"].mode()[0] #It gives the mode
df.fillna({"Calories":x},inplace=True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
x = df["Calories"].mean() #It gives the mean
df.fillna({"Calories":x},inplace=True)
df
# Out:
#     Duration        Date  Pulse  Maxpulse  Calories
# 0         60  2020/12/01    110       130     409.1
# 1         60  2020/12/02    117       145     479.0
# 2         60  2020/12/03    103       135     340.0
# 3         45  2020/12/04    109       175     282.4
# 4         45  2020/12/05    117       148     406.0
# 5         60  2020/12/06    102       127     300.0
# 6         60  2020/12/07    110       136     374.0
# 7        450  2020/12/08    104       134     253.3
# 8         30  2020/12/09    109       133     195.1
# 9         60  2020/12/10     98       124     269.0
# 10        60  2020/12/11    103       147     329.3
# 11        60  2020/12/12    100       120     250.7
# 12        60  2020/12/12    100       120     250.7
# 13        60  2020/12/13    106       128     345.3
# 14        60  2020/12/14    104       132     379.3
# 15        60  2020/12/15     98       123     275.0
# 16        60  2020/12/16     98       120     215.2
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],format='mixed')
print(df.to_string())
df
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        450 2020-12-08 00:00:00.000000000    104       134     253.3
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
df.dropna(subset=['Date'],inplace=True)

# %%
df
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        450 2020-12-08 00:00:00.000000000    104       134     253.3
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
df.loc[7,'duration'] = 45 #It creates a new column and insert 45
print(df.to_string())
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories  duration
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1       NaN
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0       NaN
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0       NaN
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4       NaN
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0       NaN
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0       NaN
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0       NaN
# 7        450 2020-12-08 00:00:00.000000000    104       134     253.3      45.0
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1       NaN
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0       NaN
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3       NaN
# ...

# %%
for x in df.index:
  if df.loc[x,'Duration']>120:
    df.loc[x,'Duration']=120

# %%
df
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories  \
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        120 2020-12-08 00:00:00.000000000    104       134     253.3
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
# To remove the rows

# %%
for x in df.index:
  if df.loc[x,'Duration']>120:
    df.drop(x,inplace=True)

# %%
df
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories  \
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        120 2020-12-08 00:00:00.000000000    104       134     253.3
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
print(df.duplicated)
# Out:
# <bound method DataFrame.duplicated of     Duration                          Date  Pulse  Maxpulse  Calories  \
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        120 2020-12-08 00:00:00.000000000    104       134     253.3
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
# Filtering

# %%
high_pulse = df[df['Pulse']>110]

# %%
print(high_pulse)
# Out:
#     Duration       Date  Pulse  Maxpulse  Calories  duration
# 1         60 2020-12-02    117       145     479.0       NaN
# 4         45 2020-12-05    117       148     406.0       NaN
# 23        60 2020-12-23    130       101     300.0       NaN

# %%
# Sorting

# %%
sorted_df = df.sort_values(by='Calories',ascending = False)
print(sorted_df)
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories  \
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 30        60 2020-12-30 00:00:00.000000000    102       129     380.3
# 14        60 2020-12-14 00:00:00.000000000    104       132     379.3
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 21        60 2020-12-21 00:00:00.000000000    108       131     364.2
# 13        60 2020-12-13 00:00:00.000000000    106       128     345.3
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 25        60 2020-12-25 00:00:00.000000000    102       126     334.5
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 19        60 2020-12-19 00:00:00.000000000    103       123     323.0
# ...

# %%
trainer_df = pd.DataFrame({
    'Date': ['2020/12/01', '2020/12/02', '2020/12/03'],
    'Trainer': ['Alex', 'Jordan', 'Taylor']
})

# Convert 'Date' column in trainer_df to datetime format
trainer_df['Date'] = pd.to_datetime(trainer_df['Date'])

# Now merge
merged_df = pd.merge(df, trainer_df, on='Date', how='left')

print(merged_df)
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories  \
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        120 2020-12-08 00:00:00.000000000    104       134     253.3
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
## Group by Duration and Calculate Average Calories

### Groups the dataset by the Duration column (i.e., how long each activity lasted).

### For each unique Duration, it computes the average Calories burned.

### Returns a Series with Duration as the index and average Calories as values.


# Group by Duration and get average Calories

avg_calories_by_duration = df.groupby('Duration')['Calories'].mean()

# Group by Pulse range (bucketed)

df['PulseRange'] = pd.cut(df['Pulse'], bins=[100, 110, 120, 130, 140, 150, 180])

grouped_stats = df.groupby('PulseRange', observed=False).agg({

    'Calories': 'mean',

    'Maxpulse': 'max'

})

print(grouped_stats)
# Out:
#             Calories  Maxpulse
# PulseRange
# (100, 110]  311.6125     175.0
# (110, 120]  442.5000     148.0
# (120, 130]  300.0000     101.0
# (130, 140]       NaN       NaN
# (140, 150]       NaN       NaN
# (150, 180]       NaN       NaN

# %%
merged_df['Trainer'].value_counts()
# Out:
# Trainer
# Alex      1
# Jordan    1
# Taylor    1
# Name: count, dtype: int64

# %%
'''Data Correlations- Finding Relationships

A great aspect of the Pandas module is the corr() method.

The corr() method calculates the relationship between each column in your data set.

df.corr()

Note: The corr() method ignores "not numeric" columns.

                      Duration     Pulse         Maxpulse    Calories

  Duration  1.000000    -0.155408  0.009403      0.922721

  Pulse     -0.155408    1.000000   0.786535      0.025120

  Maxpulse  0.009403    0.786535   1.000000      0.203814

  Calories  0.922721    0.025120   0.203814      1.000000

The Result of the corr() method is a table with a lot of numbers that represents how well the relationship is between two columns.

The number varies from -1 to 1.

1 means that there is a 1 to 1 relationship (a perfect correlation), and for this data set, each time a value went up in the first column, the other one went up as well.

0.9 is also a good relationship, and if you increase one value, the other will probably increase as well.

-0.9 would be just as good relationship as 0.9, but if you increase one value, the other will probably go down.

0.2 means NOT a good relationship, meaning that if one value goes up does not mean that the other will.

What is a good correlation? It depends on the use, but I think it is safe to say you have to have at least 0.6 (or -0.6) to call it a good correlation.

Perfect Correlation:

We can see that "Duration" and "Duration" got the number 1.000000, which makes sense, each column always has a perfect relationship with itself.

Good Correlation:

"Duration" and "Calories" got a 0.922721 correlation, which is a very good correlation, and we can predict that the longer you work out, the more calories you burn, and the other way around: if you burned a lot of calories, you probably had a long work out.

Bad Correlation:

"Duration" and "Maxpulse" got a 0.009403 correlation, which is a very bad correlation, meaning that we can not predict the max pulse by just looking at the duration of the work out, and vice versa.'''

# %%
# 1.00 is a perfect correlation

# %%
print(df.corr)   #df.corr() calculates the pairwise correlation between all numeric columns in your DataFrame.

#It returns a correlation matrix, where each cell shows the correlation coefficient r between two columns.
# Out:
# <bound method DataFrame.corr of     Duration                          Date  Pulse  Maxpulse  Calories  \
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        120 2020-12-08 00:00:00.000000000    104       134     253.3
# 8         30 2020-12-09 00:00:00.000000000    109       133     195.1
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# ...

# %%
print(df.shape)
# Out:
# (31, 7)

# %%
#Stirng operations

# %%
#.str.uppert(),.str.contains(),.str.replace()

# %%
#  Advanced Filtering and Quering
#  Using .query() and .between() for readable filters combining multiple conditions

# %%
df.query('Pulse>110 and Calories<400')
df[df['Calories'].between(200,500)]
# Out:
#     Duration                          Date  Pulse  Maxpulse  Calories  \
# 0         60 2020-12-01 00:00:00.000000000    110       130     409.1
# 1         60 2020-12-02 00:00:00.000000000    117       145     479.0
# 2         60 2020-12-03 00:00:00.000000000    103       135     340.0
# 3         45 2020-12-04 00:00:00.000000000    109       175     282.4
# 4         45 2020-12-05 00:00:00.000000000    117       148     406.0
# 5         60 2020-12-06 00:00:00.000000000    102       127     300.0
# 6         60 2020-12-07 00:00:00.000000000    110       136     374.0
# 7        120 2020-12-08 00:00:00.000000000    104       134     253.3
# 9         60 2020-12-10 00:00:00.000000000     98       124     269.0
# 10        60 2020-12-11 00:00:00.000000000    103       147     329.3
# 11        60 2020-12-12 00:00:00.000000000    100       120     250.7
# 13        60 2020-12-13 00:00:00.000000000    106       128     345.3
# ...
